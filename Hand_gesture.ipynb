# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana507/SCT_ML_4/blob/main/Hand_gesture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mediapipe
import mediapipe as mp
import cv2
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7859/2764442623.py in <cell line: 0>()
# ----> 1 import mediapipe as mp
#       2 import cv2
#       3 import os
#
# ModuleNotFoundError: No module named 'mediapipe'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os

# Try to import hands in three different ways
try:
    import mediapipe as mp
    mp_hands = mp.solutions.hands
    print("✅ Method 1 Success: mp.solutions.hands")
except:
    try:
        from mediapipe.python.solutions import hands as mp_hands
        print("✅ Method 2 Success: Deep Import")
    except:
        try:
            import mediapipe.solutions.hands as mp_hands
            print("✅ Method 3 Success: Direct Submodule")
        except Exception as e:
            print(f"❌ All import methods failed: {e}")

# If one of them worked, initialize the model
if 'mp_hands' in locals():
    hands = mp_hands.Hands(static_image_mode=True, max_num_hands=1)
    print("🚀 Hand Detection Model is READY!")
